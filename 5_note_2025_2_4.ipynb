# %%
import pandas as pd
data_simulator = pd.read_csv('./Res/simulator_data.csv')
data_simulator
# Out:
#         group                   loan_id  gender  age  amount  num_loan  \
# 0       train  /+6C2lDDYJgzzCXpn96AFA==       1   18    2000         1
# 1       train  /+6C2lDDYJgzzCXpn96AFA==       1   18    2000         1
# 2       train  /+6C2lDDYJgzzCXpn96AFA==       1   18    2000         1
# 3       train  /+6C2lDDYJgzzCXpn96AFA==       1   18    2000         1
# 4       train  /+6C2lDDYJgzzCXpn96AFA==       1   18    2000         1
# ...       ...                       ...     ...  ...     ...       ...
# 200009   test  ZWocy2KIKqJbgKZVoXZIFA==       1   30    2900         1
# 200010   test  ZWocy2KIKqJbgKZVoXZIFA==       1   30    2900         1
# 200011   test  ZWocy2KIKqJbgKZVoXZIFA==       1   30    2900         1
# 200012   test  ZWocy2KIKqJbgKZVoXZIFA==       1   30    2900         1
# 200013   test  ZWocy2KIKqJbgKZVoXZIFA==       1   30    2900         1
#
#         duration  year_ratio  diff_city  marriage  ...  y_installment  \
# 0              6          16   40421.53         0  ...              2
# 1              6          16   40421.53         0  ...              2
# 2              6          16   40421.53         0  ...              2
# 3              6          16   40421.53         0  ...              2
# 4              6          16   40421.53         0  ...              3
# ...          ...         ...        ...       ...  ...            ...
# 200009         5          18       0.00         0  ...              5
# 200010         5          18       0.00         0  ...              5
# 200011         5          18       0.00         0  ...              5
# 200012         5          18       0.00         0  ...              5
# 200013         5          18       0.00         0  ...              5
#
#         y_installment_timestep  y_state_cum_overduelength  y_remaining_debt  \
# 0                            1                          2       2000.000000
# 1                            2                          7       2000.000000
# 2                            3                          7       2000.000000
# 3                            4                          8       2000.000000
# 4                            1                          0       1666.666667
# ...                        ...                        ...               ...
# 200009                       1                          2       1740.000000
# 200010                       2                        -15       1740.000000
# 200011                       3                         24       1740.000000
# 200012                       4                         -1       1740.000000
# 200013                       4                         -1       1740.000000
#
#         y_state_capital  y_state_interests  y_state_penalty  installment_done  \
# 0            666.666667          53.333333         3.333333                 1
# 1            666.666667          53.333333        11.666667                 0
# 2            666.666667          53.333333        11.666667                 0
# 3            666.666667          53.333333        13.333333                 0
# 4            666.666667          53.333333         0.000000                 1
# ...                 ...                ...              ...               ...
# 200009      1740.000000         130.500000         8.700000                 1
# 200010      1740.000000         130.500000       -37.700000                 0
# 200011      1740.000000         130.500000        78.300000                 0
# 200012      1740.000000         130.500000         8.700000                 0
# 200013      1740.000000         130.500000         8.700000                 1
#
#         loan_done  recovery_rate_weighted
# 0               0                0.205350
# 1               0                0.000000
# 2               0                0.000000
# 3               0                0.000000
# 4               0                0.177079
# ...           ...                     ...
# 200009          0                0.000000
# 200010          0                0.000000
# 200011          0                0.000000
# 200012          0                0.000000
# 200013          1                0.000000
#
# [200014 rows x 32 columns]

# %%
# show dataset names
data_simulator.columns
# Out:
# Index(['group', 'loan_id', 'gender', 'age', 'amount', 'num_loan', 'duration',
#        'year_ratio', 'diff_city', 'marriage', 'kids', 'month_in', 'housing',
#        'edu', 'motivation', 'installment', 'installment_timestep',
#        'state_cum_overduelength', 'remaining_debt', 'state_capital',
#        'state_interests', 'state_penalty', 'y_installment',
#        'y_installment_timestep', 'y_state_cum_overduelength',
#        'y_remaining_debt', 'y_state_capital', 'y_state_interests',
#        'y_state_penalty', 'installment_done', 'loan_done',
#        'recovery_rate_weighted'],
#       dtype='object')

# %%
simulator_data_train = data_simulator.loc(data_simulator['group'] == 'train')
simulator_data_train
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/zy/vkctyqk92fg6nc3d3yhqm76h0000gn/T/ipykernel_8256/803055565.py in ?()
# ----> 1 simulator_data_train = data_simulator.loc(data_simulator['group'] == 'train')
#       2 simulator_data_train
#
# /opt/miniconda3/envs/loan/lib/python3.11/site-packages/pandas/core/indexing.py in ?(self, axis)
#     734         # we need to return a copy of ourselves
#     735         new_self = type(self)(self.name, self.obj)
#     736
#     737         if axis is not None:
# --> 738             axis_int_none = self.obj._get_axis_number(axis)
#     739         else:
#     740             axis_int_none = axis
#     741         new_self.axis = axis_int_none
#
# /opt/miniconda3/envs/loan/lib/python3.11/site-packages/pandas/core/generic.py in ?(cls, axis)
#     573     @classmethod
#     574     def _get_axis_number(cls, axis: Axis) -> AxisInt:
#     575         try:
#     576             return cls._AXIS_TO_AXIS_NUMBER[axis]
# --> 577         except KeyError:
#     578             raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#
# TypeError: unhashable type: 'Series'
